# %% [markdown]
# <a href="https://colab.research.google.com/github/Loiwj/AccumulatedPointsApp/blob/main/Chicken.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mục mới

# %%
# !git clone https://github.com/Loiwj/NCKH.git
# Out:
# Cloning into 'NCKH'...
# remote: Enumerating objects: 2934, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 2934 (delta 24), reused 28 (delta 10), pack-reused 2891
# Receiving objects: 100% (2934/2934), 412.54 MiB | 12.00 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# Updating files: 100% (2873/2873), done.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 15.9 MB/s eta 0:00:00
# ...

# %%
# %cd ./NCKH
# Out:
# /content/NCKH

# %%
# !yolo task=detect mode=train model=yolov8n.pt epochs=100 data=/content/NCKH/Detect_chicken_sex/data.yaml imgsz=640
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
